# %% [markdown]
# # Use this code for testing the random forest model

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import numpy as np
from RandomForest import RandomForest
import os
from RF_preprocessing import load_samples, preprocess_samples
from sklearn.metrics import classification_report
import pickle
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import numpy as np
# ----> 4 from RandomForest import RandomForest
#       5 import os
#       6 from RF_preprocessing import load_samples, preprocess_samples
#
# File ~/Library/CloudStorage/OneDrive-LUTUniversity/Data-Centric Engineering/Kurssit/Pattern Recognition and Machine Learning/PRML_project/Random_forest/RandomForest.py:3
#       1 # credit source:
#       2 # https://github.com/AssemblyAI-Community/Machine-Learning-From-Scratch/tree/main/05%20Random%20Forests
# ----> 3 from .DecisionTree import DecisionTree
#       4 import numpy as np
#       5 from collections import Counter
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# ## Test data preprocessing

# %%
# Replace the path to the test data if you 
samples, labels = load_samples("../training_data")
X, y = preprocess_samples(samples), np.array(labels)
print(X.shape,y.shape)
print(max([len(s) for s in samples]))
# Out:
# (1000, 512) (1000,)
# 222

# %% [markdown]
# ## Load the model

# %%
trained_model_dir = os.path.join("../trained_models")
model_name = "RF_classifier.pkl"
model_path = os.path.join(trained_model_dir, model_name)

with open(model_path, "rb") as f: 
    RF_classifier_model: RandomForest = pickle.load(f)

# %% [markdown]
# ## Test with it

# %%
# Extract a random test set form training data.
_, X_test, _, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# For external test set just feed the X and y directly to the model
# X_test = X
# y_test = y

# Test model performance
y_pred = RF_classifier_model.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        20
#            2       1.00      1.00      1.00        20
#            3       0.95      0.95      0.95        20
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#            6       1.00      1.00      1.00        20
#            7       0.95      0.95      0.95        20
#            8       1.00      1.00      1.00        20
#            9       1.00      1.00      1.00        20
#
#     accuracy                           0.99       200
#    macro avg       0.99      0.99      0.99       200
# weighted avg       0.99      0.99      0.99       200
